# %% [markdown]
# <a href="https://colab.research.google.com/github/behzadmgr-Fi/Linear-Regression/blob/main/Thesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
